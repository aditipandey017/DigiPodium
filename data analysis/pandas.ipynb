# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
penguins= sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# - analysis
#     - univariate analysis
#     - bi-variate analysis
#     - multi-variate analysis
# - loading data
#     - custom data from a variable
#     - excel data
#     - csv/ json/ etc
#     - database (sql)

# %%
students = {
    'name':['Vaibhav', 'Siya', 'Aman','Amjad', 'Sneha','Aditi','Bhupendra'],
    'college':['SRMCEM', 'SRMCEM', "KMC", "KMC", 'CU','SRMCEM','SRMCEM'],
    'dob':['25 Jan','2 Feb','2 Apr', '16 Aug', '16 Sep','17 Dec','22 May']
}
sdf = pd.DataFrame(students)
sdf
# Out:
#         name college     dob
# 0    Vaibhav  SRMCEM  25 Jan
# 1       Siya  SRMCEM   2 Feb
# 2       Aman     KMC   2 Apr
# 3      Amjad     KMC  16 Aug
# 4      Sneha      CU  16 Sep
# 5      Aditi  SRMCEM  17 Dec
# 6  Bhupendra  SRMCEM  22 May

# %%
data = pd.read_excel('c:/users/zaid/Documents/example_dataset.xlsx')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\aditi\Documents\DigiPodium\data analysis\pandas.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aditi/Documents/DigiPodium/data%20analysis/pandas.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> data = pd.read_excel('c:/users/zaid/Documents/example_dataset.xlsx')
#       <a href='vscode-notebook-cell:/c%3A/Users/aditi/Documents/DigiPodium/data%20analysis/pandas.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> data
#
# File c:\Users\aditi\miniconda3\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
# ...

# %%
penguins.drop(index=2)  #drop row 3
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop(index=range(10))  #drop row 10
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 10        3300.0     NaN
# 11        3700.0     NaN
# ...

# %%
np.nan
# Out:
# nan

# %% [markdown]
# Find the missing no. of values in each columns

# %%
sns.heatmap(penguins.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(penguins.isnull(), cbar=False)  #overall null value visualisation
# Out:
# <Axes: >

# %%
penguins.isnull().sum().plot(kind='bar')    #columnwise null value visualisation
# Out:
# <Axes: >

# %%
penguins.dropna()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.dropna().shape
# Out:
# (333, 7)

# %%
penguins.dropna(inplace= True)
print(penguins.shape)
# Out:
# (333, 7)

# %%
penguins.drop_duplicates(subset=['species'])
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 152  Chinstrap      Dream            46.5           17.9              192.0
# 220     Gentoo     Biscoe            46.1           13.2              211.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 152       3500.0  Female
# 220       4500.0  Female

# %%
penguins.drop_duplicates(subset=['bill_length_mm'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 326  Gentoo     Biscoe            41.7           14.7              210.0
# 327  Gentoo     Biscoe            53.4           15.8              219.0
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 337  Gentoo     Biscoe            48.8           16.2              222.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.sort_values(by='sex')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 172  Chinstrap   Dream            42.4           17.3              181.0
# 136     Adelie   Dream            35.6           17.5              191.0
# 138     Adelie   Dream            37.0           16.5              185.0
# 272     Gentoo  Biscoe            45.1           14.4              210.0
# 140     Adelie   Dream            40.2           17.1              193.0
# ..         ...     ...             ...            ...                ...
# 163  Chinstrap   Dream            51.7           20.3              194.0
# 165  Chinstrap   Dream            52.0           18.1              201.0
# 167  Chinstrap   Dream            50.5           19.6              201.0
# 145     Adelie   Dream            39.0           18.7              185.0
# 343     Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 172       3600.0  Female
# 136       3175.0  Female
# ...

# %%
penguins.sort_values(by='sex', ascending=False)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 119     Adelie  Torgersen            41.1           18.6              189.0
# 179  Chinstrap      Dream            49.5           19.0              200.0
# 181  Chinstrap      Dream            52.8           20.0              205.0
# 183  Chinstrap      Dream            54.2           20.8              201.0
# ..         ...        ...             ...            ...                ...
# 206  Chinstrap      Dream            42.5           17.3              187.0
# 74      Adelie  Torgersen            35.5           17.5              190.0
# 208  Chinstrap      Dream            45.2           16.6              191.0
# 72      Adelie  Torgersen            39.6           17.2              196.0
# 172  Chinstrap      Dream            42.4           17.3              181.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...

# %%
penguins.sort_values(by=['sex','island'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie     Biscoe            37.8           18.3              174.0
# 22   Adelie     Biscoe            35.9           19.2              189.0
# 25   Adelie     Biscoe            35.3           18.9              187.0
# 27   Adelie     Biscoe            40.5           17.9              187.0
# 28   Adelie     Biscoe            37.9           18.6              172.0
# ..      ...        ...             ...            ...                ...
# 123  Adelie  Torgersen            41.4           18.5              202.0
# 125  Adelie  Torgersen            40.6           19.0              199.0
# 127  Adelie  Torgersen            41.5           18.3              195.0
# 129  Adelie  Torgersen            44.1           18.0              210.0
# 131  Adelie  Torgersen            43.1           19.2              197.0
#
#      body_mass_g     sex
# 20        3400.0  Female
# 22        3800.0  Female
# ...

# %%
penguins.sort_values(by='bill_depth_mm')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 244  Gentoo     Biscoe            42.9           13.1              215.0
# 220  Gentoo     Biscoe            46.1           13.2              211.0
# 268  Gentoo     Biscoe            44.9           13.3              213.0
# 228  Gentoo     Biscoe            43.3           13.4              209.0
# 236  Gentoo     Biscoe            42.0           13.5              210.0
# ..      ...        ...             ...            ...                ...
# 35   Adelie      Dream            39.2           21.1              196.0
# 61   Adelie     Biscoe            41.3           21.1              195.0
# 49   Adelie      Dream            42.3           21.2              191.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
#
#      body_mass_g     sex
# 244       5000.0  Female
# 220       4500.0  Female
# ...

# %% [markdown]
# Datatypes in pandas
# - int
# - float
# - boolean
# - string (not understood by pandas by default, unless you specify)
# - object (if datatype is not understood by pandas then object is used (Default) )
# - datetime
# - category  #categorical data (neither string nor number)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
penguins.dtypes # datatypes of columns
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguins.select_dtypes(include='number')
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [333 rows x 4 columns]

# %%
penguins.select_dtypes(include='object')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %%
penguins.select_dtypes(exclude='number')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %% [markdown]
# change datatype of column

# %%
penguins['island'].astype('category')   #not actually applied on the column
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 333, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
penguins['island']=penguins['island'].astype('category')  # casting object to category

# %%
penguins.dtypes
# Out:
# species                object
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                    object
# dtype: object

# %%
penguins.sex=penguins.sex.astype('bool')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g   sex
# 0       3750.0  True
# 1       3800.0  True
# 2       3250.0  True
# 4       3450.0  True
# 5       3650.0  True

# %% [markdown]
# ### Simple Visualisation -univarient(single column)
# - for numerical data
#     - line plot -> .plot()
#     - bar plot -> .plot(kind='bar')
#     - histogram -> .plot(kind='box')
#     - area -> .plot(kind='area')
#     - histpgram -> .hist()
# - For Categorical data
#     -

# %%
penguins['bill_depth_mm']
# Out:
# 0      18.7
# 1      17.4
# 2      18.0
# 4      19.3
# 5      20.6
#        ...
# 338    13.7
# 340    14.3
# 341    15.7
# 342    14.8
# 343    16.1
# Name: bill_depth_mm, Length: 333, dtype: float64

# %%
penguins['bill_depth_mm'].hist()
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='area', figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='box', figsize=(8,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='box', figsize=(8,5), vert=False)
# Out:
# <Axes: >

# %%
penguins['bill_length_mm'].plot(kind='area', figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins['body_mass_g'].plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins['flipper_length_mm'].plot(kind='box', figsize=(8,5))
# Out:
# <Axes: >

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
penguins['island'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='island'>

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins[['bill_depth_mm','bill_length_mm']].hist()
# Out:
# array([[<Axes: title={'center': 'bill_depth_mm'}>,
#         <Axes: title={'center': 'bill_length_mm'}>]], dtype=object)

# %% [markdown]
# putting columns visualization in subplots

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(layout=(1,2),
                                                  subplots=True,
                                                  figsize=(15,5))
# Out:
# array([[<Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# Power of Seaborn

# %%
sns.displot(data=penguins, x='bill_depth_mm')

# %%
sns.displot(data=penguins, x='bill_depth_mm',hue='island')

# %%
sns.displot(data=penguins, x='body_mass_g',hue='island')

# %%
sns.countplot(data=penguins, x='island', hue='species')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# Bivariate Analysis
# - Scatter plot(numeric vs numeric)
# - violin plot(alternative to box plot)
# - pair plot

# %%
sns.scatterplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', hue='species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', hue='island')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette('hot')
# Out:
# [(0.41221438595965454, 0.0, 0.0),
#  (0.7931236159737438, 0.0, 0.0),
#  (1.0, 0.16372618247436524, 0.0),
#  (1.0, 0.544607916482724, 0.0),
#  (1.0, 0.9151955495719379, 0.0),
#  (1.0, 1.0, 0.44411709117591475)]

# %%
sns.set_palette()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\aditi\Documents\DigiPodium\data analysis\pandas.ipynb Cell 62 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aditi/Documents/DigiPodium/data%20analysis/pandas.ipynb#Y115sZmlsZQ%3D%3D?line=0'>1</a> sns.set_palette()
#
# TypeError: set_palette() missing 1 required positional argument: 'palette'

# %%
sns.scatterplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', hue='island')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', hue='island')

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', hue='island', style='island')

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', size="island")

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', size="island", sizes=(15, 200))

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', kind='line')

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar=None,
)

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar="sd",
)

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', kind='line', errorbar='sd')

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', kind='line',
             errorbar='sd',estimator=None)    #estimator is related to algorithm

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', kind='line', hue="species",)

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', kind='line', hue="species",style='island')

# %%
sns.relplot(data=penguins, x='bill_depth_mm',y= 'bill_length_mm', kind='line', hue="species",style='island',dashes=False, markers=True)

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal",
    hue="region", style="event",
)
